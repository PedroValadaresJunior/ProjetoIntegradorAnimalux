# %% [markdown]
# # Notebook de Execução

# %%
# %run bases.ipynb
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df_base_usuarios
# Out:
#      user_id              nome  idade                cidade estado  \
# 0          0            Milena     56                Araújo     TO
# 1          1  Gustavo Henrique     40         Rios do Norte     ES
# 2          2             Maitê     19               da Mota     BA
# 3          3            Nicole     39      da Luz do Amparo     RN
# 4          4           Vitória     33   Araújo dos Dourados     ES
# ..       ...               ...    ...                   ...    ...
# 495      495      Maria Helena     24  Costela de Fernandes     ES
# 496      496       Ana Beatriz     46       Cassiano do Sul     SC
# 497      497     Henry Gabriel     44               Barbosa     PA
# 498      498             Diogo     57     Nogueira do Galho     SP
# 499      499           Daniela     51              Mendonça     TO
#
#     tipo_residencia  qtd_animais comportamento_dono   latitude  longitude
# 0       Apartamento            2              ativo -31.165652 -52.203090
# ...

# %%
df_pets
# Out:
#      pet_id  user_id        nome_pet   especie       raca  idade_pet  \
# 0         0        0          Rebeca  Cachorro  Chihuahua         10
# 1         1        0       Ana Laura  Cachorro    Bulldog          7
# 2         2        1            José  Cachorro     Poodle          5
# 3         3        2  Maria Fernanda  Cachorro  Chihuahua          0
# 4         4        2          Olívia      Gato  Vira-lata          3
# ..      ...      ...             ...       ...        ...        ...
# 734     734      496            Gael  Cachorro    Bulldog          4
# 735     735      497           Sarah      Gato     Siamês          0
# 736     736      498         Kamilly  Cachorro    Bulldog          0
# 737     737      499         Emanuel      Gato  Vira-lata          9
# 738     738      499            Maya      Gato  Vira-lata          7
#
#      castrado sociavel    porte    perfil_pet
# 0       False    Média   Grande      protetor
# ...

# %%
df_comportamentos_app
# Out:
#       user_id data_acesso  curtidas  rejeicoes  tempo_ativo_min  \
# 0           1  2025-05-06        11          3               25
# 1           1  2025-05-04        16          3               26
# 2           1  2025-04-29        11          5               26
# 3           2  2025-05-07        12          3               27
# 4           3  2025-05-06         7          4                5
# ...       ...         ...       ...        ...              ...
# 1183      499  2025-05-09        10          2               16
# 1184      499  2025-05-11        12          6               21
# 1185      500  2025-05-14         7          6               19
# 1186      500  2025-05-16        10          5               15
# 1187      500  2025-05-08         9          8               26
#
#       visitas_na_semana
# 0                     3
# 1                     1
# 2                     3
# 3                     5
# 4                     2
# ...                 ...
# ...

# %%
df_compras_petshop
# Out:
#       user_id data_compra tipo_produto   valor
# 0           1  2025-05-14    acessório  160.34
# 1           1  2025-05-08    brinquedo   48.08
# 2           1  2025-03-15    acessório  175.91
# 3           1  2025-05-05    acessório   23.71
# 4           2  2025-03-02      remédio  188.94
# ...       ...         ...          ...     ...
# 1534      500  2025-05-09      petisco  116.33
# 1535      500  2025-05-07    brinquedo   26.29
# 1536      500  2025-04-15    brinquedo   25.40
# 1537      500  2025-05-20    brinquedo  110.83
# 1538      500  2025-03-22    acessório   50.43
#
# [1539 rows x 4 columns]
